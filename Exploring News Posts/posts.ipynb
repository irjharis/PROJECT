# %% [markdown]
# # Exploring Hacker News Posts

# %% [markdown]
# In this project, we'll work with a data set of submissions to popular technology site [Hacker News](https://news.ycombinator.com/). Hacker News is a site where user-submitted stories (known as `"posts"`) are voted and commented upon.

# %% [markdown]
# We're specifically interested in posts whose titles begin with either **Ask HN** or **Show HN**. Users submit `Ask HN` posts to ask the Hacker News community a specific question

# %% [markdown]
# Likewise, users submit `Show HN` posts to show the Hacker News community a project, product, or just generally something interesting.

# %% [markdown]
# We'll compare these two types of posts (i.e Ask HN posts and Show HN Posts) to determine the following:
#
# 1. Do `Ask HN` or `Show HN` receive more comments on average?
#
# 2. Do posts created at a certain time receive more comments on average?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hn = pd.read_csv("news_posts.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the 'flights' dataset
flights_data = sns.load_dataset('flights')

# Create a line chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='year', y='passengers', data=flights_data)
plt.title('Passenger Count Over Years')
plt.xlabel('Year')
plt.ylabel('Passengers')
plt.show()
# Out:
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset('tips')
data.info()

import matplotlib.pyplot as plt

# Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='total_bill', y='tip', data=data, hue='sex', palette='Set2')
plt.title('Scatter Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.legend(title='Sex')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HMHSM\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
hn.head()
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  10975351  How to Use Open Source and Shut the Fuck Up at...
# 2  11964716  Florida DJs May Face Felony for April Fools' W...
# 3  11919867       Technology ventures: From Idea to Enterprise
# 4  10301696  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...          39
# 2  http://www.thewire.com/entertainment/2013/04/f...           2
# 3  https://www.amazon.com/Technology-Ventures-Ent...           3
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...           8
#
#    num_comments      author       created_at
# 0            52    ne0phyte   8/4/2016 11:52
# 1            10      josep2  1/26/2016 19:30
# 2             1    vezycash  6/23/2016 22:20
# 3             1     hswarna   6/17/2016 0:01
# 4             2  walterbell   9/30/2015 4:12

# %%
hn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
hn = pd.read_csv("news_posts.csv", parse_dates=["created_at"])

# %%
hn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 1.1+ MB

# %%
hn = pd.read_csv("news_posts.csv")

# %%
hn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
hn["created_at"] = pd.to_datetime(hn["created_at"])

# %%
hn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 1.1+ MB

# %%
hn.columns
# Out:
# Index(['id', 'title', 'url', 'num_points', 'num_comments', 'author',
#        'created_at'],
#       dtype='object')

# %%
hn[['created_at','id', 'title', 'url',
    'num_points', 'num_comments', 'author']].head()
# Out:
#            created_at        id  \
# 0 2016-08-04 11:52:00  12224879
# 1 2016-01-26 19:30:00  10975351
# 2 2016-06-23 22:20:00  11964716
# 3 2016-06-17 00:01:00  11919867
# 4 2015-09-30 04:12:00  10301696
#
#                                                title  \
# 0                          Interactive Dynamic Video
# 1  How to Use Open Source and Shut the Fuck Up at...
# 2  Florida DJs May Face Felony for April Fools' W...
# 3       Technology ventures: From Idea to Enterprise
# 4  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...          39
# 2  http://www.thewire.com/entertainment/2013/04/f...           2
# 3  https://www.amazon.com/Technology-Ventures-Ent...           3
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...           8
#
#    num_comments      author
# 0            52    ne0phyte
# 1            10      josep2
# 2             1    vezycash
# 3             1     hswarna
# 4             2  walterbell

# %%
hn = hn[['created_at','id', 'title', 'url',
    'num_points', 'num_comments', 'author']]

# %%
hn.head()
# Out:
#            created_at        id  \
# 0 2016-08-04 11:52:00  12224879
# 1 2016-01-26 19:30:00  10975351
# 2 2016-06-23 22:20:00  11964716
# 3 2016-06-17 00:01:00  11919867
# 4 2015-09-30 04:12:00  10301696
#
#                                                title  \
# 0                          Interactive Dynamic Video
# 1  How to Use Open Source and Shut the Fuck Up at...
# 2  Florida DJs May Face Felony for April Fools' W...
# 3       Technology ventures: From Idea to Enterprise
# 4  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...          39
# 2  http://www.thewire.com/entertainment/2013/04/f...           2
# 3  https://www.amazon.com/Technology-Ventures-Ent...           3
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...           8
#
#    num_comments      author
# 0            52    ne0phyte
# 1            10      josep2
# 2             1    vezycash
# 3             1     hswarna
# 4             2  walterbell

# %%
ask_bol =  hn["title"].str.lower().str.startswith("ask hn")
show_bol = hn["title"].str.lower().str.startswith("show hn")

# %%
ask_posts = hn[ask_bol].copy()
show_posts = hn[show_bol].copy()

# %%
ask_posts.head()
# Out:
#             created_at        id  \
# 7  2016-08-16 09:55:00  12296411
# 17 2015-11-22 13:43:00  10610020
# 22 2016-05-02 10:14:00  11610310
# 30 2016-08-02 14:20:00  12210105
# 31 2015-10-15 16:38:00  10394168
#
#                                                 title  url  num_points  \
# 7         Ask HN: How to improve my personal website?  NaN           2
# 17  Ask HN: Am I the only one outraged by Twitter ...  NaN          28
# 22  Ask HN: Aby recent changes to CSS that broke m...  NaN           1
# 30    Ask HN: Looking for Employee #3 How do I do it?  NaN           1
# 31  Ask HN: Someone offered to buy my browser exte...  NaN          28
#
#     num_comments        author
# 7              6  ahmedbaracat
# 17            29          tkfx
# 22             1     polskibus
# 30             3        sph130
# 31            17      roykolak

# %%
show_posts.tail()
# Out:
#                created_at        id  \
# 19993 2016-03-04 04:50:00  11222099
# 19999 2016-05-20 03:48:00  11735438
# 20014 2015-09-10 22:17:00  10200913
# 20065 2016-04-07 03:04:00  11444393
# 20070 2016-07-23 11:35:00  12149183
#
#                                                    title  \
# 19993  Show HN: Geocoding API built with government o...
# 19999  Show HN: Decorating: Animated pulsed for your ...
# 20014                           Show HN: Idea to startup
# 20065     Show HN: PhantomJsCloud, Headless Browser SaaS
# 20070  Show HN: Parse recipe ingredients using JavaSc...
#
#                                                 url  num_points  num_comments  \
# 19993                             https://latlon.io           6             6
# 19999        https://github.com/ryukinix/decorating           3             1
# 20014                     https://ideatostartup.org          14            17
# 20065                    https://PhantomJsCloud.com           2             1
# 20070  https://github.com/herkyl/ingredients-parser           6             2
#
#                author
# 19993       evanmarks
# 19999           lerax
# 20014      nikhildaga
# 20065        novaleaf
# 20070  zongitsrinzler

# %%
other_posts = hn[~ (ask_bol | show_bol)]
other_posts.head()
# Out:
#            created_at        id  \
# 0 2016-08-04 11:52:00  12224879
# 1 2016-01-26 19:30:00  10975351
# 2 2016-06-23 22:20:00  11964716
# 3 2016-06-17 00:01:00  11919867
# 4 2015-09-30 04:12:00  10301696
#
#                                                title  \
# 0                          Interactive Dynamic Video
# 1  How to Use Open Source and Shut the Fuck Up at...
# 2  Florida DJs May Face Felony for April Fools' W...
# 3       Technology ventures: From Idea to Enterprise
# 4  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...          39
# 2  http://www.thewire.com/entertainment/2013/04/f...           2
# 3  https://www.amazon.com/Technology-Ventures-Ent...           3
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...           8
#
#    num_comments      author
# 0            52    ne0phyte
# 1            10      josep2
# 2             1    vezycash
# 3             1     hswarna
# 4             2  walterbell

# %%
ask_avg_com = ask_posts["num_comments"].mean()
show_avg_com = show_posts["num_comments"].mean()

print(ask_avg_com, show_avg_com)
# Out:
# 14.038417431192661 10.31669535283993

# %%
avg_comm = pd.Series({"ask_com":ask_avg_com, "show_com":show_avg_com})

# %%
avg_comm
# Out:
# ask_com     14.038417
# show_com    10.316695
# dtype: float64

# %%
hn["num_comments"].head(2)
# Out:
# 0    52
# 1    10
# Name: num_comments, dtype: int64

# %%
avg_comm.plot.bar()
# Out:
# <Axes: >

# %%
avg_comm.plot.bar()
plt.show()

# %%
avg_comm.plot.barh(title = "Comparision of posts' comments")
plt.show()

# %%
ask_posts["hours"] = ask_posts["created_at"].dt.hour

# %%
ask_posts.head()
# Out:
#             created_at        id  \
# 7  2016-08-16 09:55:00  12296411
# 17 2015-11-22 13:43:00  10610020
# 22 2016-05-02 10:14:00  11610310
# 30 2016-08-02 14:20:00  12210105
# 31 2015-10-15 16:38:00  10394168
#
#                                                 title  url  num_points  \
# 7         Ask HN: How to improve my personal website?  NaN           2
# 17  Ask HN: Am I the only one outraged by Twitter ...  NaN          28
# 22  Ask HN: Aby recent changes to CSS that broke m...  NaN           1
# 30    Ask HN: Looking for Employee #3 How do I do it?  NaN           1
# 31  Ask HN: Someone offered to buy my browser exte...  NaN          28
#
#     num_comments        author  hours
# 7              6  ahmedbaracat      9
# 17            29          tkfx     13
# 22             1     polskibus     10
# 30             3        sph130     14
# 31            17      roykolak     16

# %%
ask_posts.groupby("hours")["num_comments"].mean().sort_values(ascending = False)
# Out:
# hours
# 15    38.594828
# 2     23.810345
# 20    21.525000
# 16    16.796296
# 21    16.009174
# 13    14.741176
# 10    13.440678
# 14    13.233645
# 18    13.201835
# 17    11.460000
# 1     11.383333
# 11    11.051724
# 19    10.800000
# 8     10.250000
# 5     10.086957
# 12     9.410959
# 6      9.022727
# 0      8.127273
# 23     7.985294
# 7      7.852941
# 3      7.796296
# 4      7.170213
# 22     6.746479
# 9      5.577778
# Name: num_comments, dtype: float64

# %%
ask_posts.shape
# Out:
# (1744, 8)

# %%
ask_posts.to_csv("hn_askposts.csv", index = False)

# %%
h_comm = ask_posts.groupby("hours")["num_comments"].mean().sort_values(ascending = False)

# %%
h_comm.index.name=None

# %%
h_comm.head()
# Out:
# 15    38.594828
# 2     23.810345
# 20    21.525000
# 16    16.796296
# 21    16.009174
# Name: num_comments, dtype: float64

# %%
plt.figure(figsize=(20,8))
h_comm.plot.barh(title="Average comments at ask posts")
plt.xticks(rotation=75)
# plt.yticks(rotation=20)
plt.show()

# %%
h_comm_df = pd.DataFrame(h_comm)

# %%
h_comm_df.head()
# Out:
#     num_comments
# 15     38.594828
# 2      23.810345
# 20     21.525000
# 16     16.796296
# 21     16.009174

# %%
x,y =  15,16
x
# Out:
# 15

# %%
y
# Out:
# 16

# %%
for i, v in h_comm_df.iterrows():
    print(v.values[0])
# Out:
# 38.5948275862069
# 23.810344827586206
# 21.525
# 16.796296296296298
# 16.009174311926607
# 14.741176470588234
# 13.440677966101696
# 13.233644859813085
# 13.20183486238532
# 11.46
# 11.383333333333333
# 11.051724137931034
# 10.8
# 10.25
# 10.08695652173913
# 9.41095890410959
# 9.022727272727273
# 8.127272727272727
# 7.985294117647059
# 7.852941176470588
# 7.796296296296297
# 7.170212765957447
# 6.746478873239437
# 5.5777777777777775

# %%
print("Top 5 hours")

for index, value in h_comm_df.head().iterrows():
    hour = index
    comm = value.values[0]
    print(f'There are {comm:.2f} commnents at {hour} hours')
# Out:
# Top 5 hours
# There are 38.59 commnents at 15 hours
# There are 23.81 commnents at 2 hours
# There are 21.52 commnents at 20 hours
# There are 16.80 commnents at 16 hours
# There are 16.01 commnents at 21 hours

# %%
show_posts["hours"]=show_posts["created_at"].dt.hour

# %%
show_posts.head()
# Out:
#             created_at        id  \
# 13 2015-11-25 14:03:00  10627194
# 39 2015-11-29 22:46:00  10646440
# 46 2016-04-28 18:05:00  11590768
# 84 2016-07-28 07:11:00  12178806
# 97 2016-01-09 20:45:00  10872799
#
#                                                 title  \
# 13  Show HN: Wio Link  ESP8266 Based Web of Things...
# 39                Show HN: Something pointless I made
# 46  Show HN: Shanhu.io, a programming playground p...
# 84  Show HN: Webscope  Easy way for web developers...
# 97  Show HN: GeoScreenshot  Easily test Geo-IP bas...
#
#                                url  num_points  num_comments      author  \
# 13            https://iot.seeed.cc          26            22     kfihihc
# 39         http://dn.ht/picklecat/         747           102     dhotson
# 46               https://shanhu.io           1             1       h8liu
# 84          http://webscopeapp.com           3             3   fastbrick
# 97  https://www.geoscreenshot.com/           1             9  kpsychwave
#
#     hours
# 13     14
# 39     22
# 46     18
# 84      7
# 97     20

# %%
show_posts.groupby("hours")["num_comments"].mean().sort_values(ascending=False)
# Out:
# hours
# 18    15.770492
# 0     15.709677
# 14    13.441860
# 23    12.416667
# 22    12.391304
# 12    11.803279
# 16    11.655914
# 7     11.500000
# 11    11.159091
# 3     10.629630
# 20    10.200000
# 19     9.800000
# 17     9.795699
# 9      9.700000
# 13     9.555556
# 4      9.500000
# 6      8.875000
# 1      8.785714
# 10     8.250000
# 15     8.102564
# 21     5.787234
# 8      4.852941
# 2      4.233333
# 5      3.052632
# Name: num_comments, dtype: float64

# %%
show_posts.to_csv("hn_showposts.csv", index = False)

# %%
s_comm = show_posts.groupby("hours")["num_comments"].mean().sort_values(ascending = False)

# %%
plt.figure(figsize=(20,8))
s_comm.plot.barh(title="Average comments at show posts")
plt.xticks(rotation=75)
# plt.yticks(rotation=20)
plt.show()

# %%
s_comm_df = pd.DataFrame(s_comm)

# %%
s_comm_df.head()
# Out:
#        num_comments
# hours
# 18        15.770492
# 0         15.709677
# 14        13.441860
# 23        12.416667
# 22        12.391304

# %%
s_comm_df.index.name=None

# %%
print("Top 5 hours")

for index, value in s_comm_df.head().iterrows():
    hour = index
    comm = value.values[0]
    print(f'There are {comm:.2f} commnents at {hour} hours')
# Out:
# Top 5 hours
# There are 15.77 commnents at 18 hours
# There are 15.71 commnents at 0 hours
# There are 13.44 commnents at 14 hours
# There are 12.42 commnents at 23 hours
# There are 12.39 commnents at 22 hours
